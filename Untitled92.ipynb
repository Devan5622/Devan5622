# %% [markdown]
# <a href="https://colab.research.google.com/github/Devan5622/Devan5622/blob/main/Untitled92.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

import keras

from keras.preprocessing.image import ImageDataGenerator, img_to_array , load_img
from keras.applications.vgg19 import VGG19, preprocess_input , decode_predictions

# %%
 #Explorative Data Analysis
 len(os.listdir("/content/drive/MyDrive/Alzheimer-Dataset/train") )
# Out:
# 4

# %%
train_datagen = ImageDataGenerator(zoom_range=0.5, shear_range=0.3, preprocessing_function=preprocess_input)

val_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

# %%
train=train_datagen.flow_from_directory(directory="/content/drive/MyDrive/Alzheimer-Dataset/train", 
                                        target_size=(256,256), 
                                        batch_size=32)
val=val_datagen.flow_from_directory(directory="/content/drive/MyDrive/Alzheimer-Dataset/test", 
                                        target_size=(256,256), 
                                        batch_size=32)
# Out:
# Found 5121 images belonging to 4 classes.
# Found 1279 images belonging to 4 classes.

# %%
t_img, label=train.next()

# %%
t_img.shape
# Out:
# (32, 256, 256, 3)

# %%
def plotImage(img_arr, label):

 for im,l in zip(img_arr , label):
  plt.figure(figsize=(5,5))
  plt.imshow(img/255)
  plt.show()

# %%
from keras.layers import Dense, Flatten
from keras.models import Model
from keras.applications.vgg19 import VGG19
import keras

# %%
base_model=VGG19(input_shape=(256,256,3),include_top=False)
# Out:
# ...
# 80150528/80134624 [==============================] - 2s 0us/step

# %%
for layer in base_model.layers:
  layer.trainable=False
  base_model.summary()
# Out:
# Model: "vgg19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_1 (InputLayer)        [(None, 256, 256, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 256, 256, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 256, 256, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 128, 128, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 128, 128, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 128, 128, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 64, 64, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 64, 64, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 32, 32, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 32, 32, 512)       1180160
#
# ...

# %%
from sys import base_exec_prefix
X=Flatten()(base_model.output)

X=Dense(units= 4 , activation='softmax') (X)

#Creating our Model
model=Model(base_model.input, X)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_1 (InputLayer)        [(None, 256, 256, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 256, 256, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 256, 256, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 128, 128, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 128, 128, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 128, 128, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 64, 64, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 64, 64, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 32, 32, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 32, 32, 512)       1180160
#
# ...

# %%
model.compile(optimizer= 'adam' , loss=keras.losses.categorical_crossentropy , metrics= ['accuracy'])

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping

#early stopping
es = EarlyStopping(monitor='val_accuracy', min_delta=0.01,patience=3, verbose=1)

#model check point

mc=ModelCheckpoint(filepath="best_model.h5",
                   monitor='val_accuracy',
                   min_delta=0.01,
                   patience=3,
                   verbose=1,
                   save_best_only=True)
cb=[es,mc]

# %%
his=model.fit_generator(train , 
                        steps_per_epoch=16, 
                        epochs=50, 
                        verbose=1, 
                        callbacks=cb, 
                        validation_data=val, 
                        validation_steps=16)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   import sys
# Epoch 1/50
# 16/16 [==============================] - ETA: 0s - loss: 16.4718 - accuracy: 0.4160
# Epoch 1: val_accuracy improved from -inf to 0.48438, saving model to best_model.h5
# 16/16 [==============================] - 781s 49s/step - loss: 16.4718 - accuracy: 0.4160 - val_loss: 10.8362 - val_accuracy: 0.4844
# Epoch 2/50
# 16/16 [==============================] - ETA: 0s - loss: 10.9996 - accuracy: 0.4824
# Epoch 2: val_accuracy improved from 0.48438 to 0.51367, saving model to best_model.h5
# 16/16 [==============================] - 748s 47s/step - loss: 10.9996 - accuracy: 0.4824 - val_loss: 12.5486 - val_accuracy: 0.5137
# Epoch 3/50
# 16/16 [==============================] - ETA: 0s - loss: 10.6207 - accuracy: 0.4844
# ...
